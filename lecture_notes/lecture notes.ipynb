# %% [markdown]
# ### simple and weighted games
# ![IMG_3208.jpg](attachment:e51b26c8-ba9f-4b19-9382-785f9f4c6af8.jpg)
#
# ### L^m(v) for the set of maximal losing
# ![IMG_3209.jpg](attachment:d0d0cc0c-d422-473f-a0a1-a22a307329db.jpg)
#
# ### to this end and assume that  (quota means threshold
# ![IMG_3210.jpg](attachment:8202a74d-8285-41b8-94aa-353b21c334f8.jpg)
#
# ### remark: we have that v is weighted
# ![IMG_3211.jpg](attachment:d1867dba-37a8-488e-b368-638194128dba.jpg)
#
# ### lemma: for a given simple game
# ![IMG_3212.jpg](attachment:cddf92fc-370a-4e08-af2e-02afcc990081.jpg)
#
# ![IMG_3214.jpg](attachment:d0ac6b2e-3090-4eb7-a6c3-d8ca215b555b.jpg)
